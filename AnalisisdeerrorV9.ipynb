# %%
# %%html
#
# <!DOCTYPE html>
# <html>
#     <body style="background-color: rgb(255, 255, 255);">
#     <h1 style="color: cyan; font-size: 50px; font-family: 'Courier New'; background-color: rgb(255, 255, 255); border: 0px; padding: 0px; margin: 0px"><b><center>Analisis de error de Esfuerzos</center></b></h1>
#     <h2 style="color: cyan; font-size: 20px; font-family: 'Courier New'; background-color: rgb(255, 255, 255); border: 0px; padding: 0px"><b><center>Parte del proyecto de tesis de: Aguilar Hancco Junior Joel</center></b></h1>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
#     <body style="background-color: rgb(0, 0, 0);">
#     <h1 style="color: cyan; font-size: 50px; font-family: 'Courier New'; background-color: rgb(0, 0, 0); border: 0px; padding: 0px; margin: 0px"><b><center>Analisis de error de Esfuerzos</center></b></h1>
#     <h2 style="color: cyan; font-size: 20px; font-family: 'Courier New'; background-color: rgb(0, 0, 0); border: 0px; padding: 0px"><b><center>Parte del proyecto de tesis de: Aguilar Hancco Junior Joel</center></b></h1>
# </html>

# %%
import numpy as np
import bqplot as bq
import ipywidgets as ipw
from bqplot import pyplot as bplt

# %%
HTMLs_names = ['Analisis de:', 'Formula 1', 'Formula 2', 'Formula 3', 'Formula 4', 'I:', 'Relacion:', 'R:', 'Data:', 'M1', 'M2', '% Error', 'r:', 'Esfuerzos maximos:', 'Relacion τ1 / τ2:', 'Bernoulli vs Timoshenko']
HTMLs = [ipw.HTML(value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{name}</b></font>", layout=ipw.Layout(width='auto', height='auto', margin='0px', padding='0px 0px 2px 0px', border='0px')) for name in HTMLs_names]

HTMLMath1 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_1=\frac{M_{xz}R}{I}$$",
)

HTMLMath2 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_2=\frac{M_{xy}R}{I}$$",
)

HTMLMath3 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_3=\frac{M_{xz}R}{I\sqrt{2}}+\frac{M_{xy}R}{I\sqrt{2}}$$",
)

HTMLMath4 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_4=\frac{R}{I}\sqrt{M_{xz}^2+M_{xy}^2}$$",
)

HTMLMath5 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\tau_p=\sqrt{\left(\frac{\sigma}{2}\right)^2+\left(\tau_1\pm\tau_2\right)^2}$$",
)

HTMLMath6 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_p=\frac{\sigma}{2}+\sqrt{\left(\frac{\sigma}{2}\right)^2+\left(\tau_1\pm\tau_2\right)^2}$$",
)

HTMLMath7 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\tau_t=\sqrt{\sigma^2+4\left(\tau_1\pm\tau_2\right)^2}$$",
)

HTMLMath8 = ipw.HTMLMath(
    value = r"<font size = '3'; font color = 'cyan'>$$\sigma_v=\sqrt{\sigma^2+3\left(\tau_1\pm\tau_2\right)^2}$$",
)

HTML1      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>0</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML2      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML3      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML4      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML5      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML6      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>R/r = 1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

HTML7      = ipw.HTML(
    value  = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>1</b></font>",
    layout = ipw.Layout(width='auto', height='auto')
)

Dropdown1   = ipw.Dropdown(
    options = ['Esfuerzos flexionantes', 'Esfuerzos cortantes'],
    value   ='Esfuerzos flexionantes',
    layout  = ipw.Layout(width='auto', margin='15px 0px 15px 0px')
)
def tipo(esfuerzo):
    if esfuerzo == 'Esfuerzos flexionantes':
        HTMLMath1.value = r"<font size = '3'; font color = 'cyan'>$$\sigma_1=\frac{M_{xz}R}{I}$$"
        HTMLMath2.value = r"<font size = '3'; font color = 'cyan'>$$\sigma_2=\frac{M_{xy}R}{I}$$"
        HTMLMath3.value = r"<font size = '3'; font color = 'cyan'>$$\sigma_3=\frac{M_{xz}R}{I\sqrt{2}}+\frac{M_{xy}R}{I\sqrt{2}}$$"
        HTMLMath4.value = r"<font size = '3'; font color = 'cyan'>$$\sigma_4=\frac{R}{I}\sqrt{M_{xz}^2+M_{xy}^2}$$" 
        HTMLs[9].value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>M1</b></font>"
        HTMLs[10].value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>M2</b></font>"
    elif esfuerzo == 'Esfuerzos cortantes':
        HTMLMath1.value = r"<font size = '3'; font color = 'cyan'>$$\tau_1=\frac{4\left(R^2-Rr-r^2\right)V_y}{3\pi\left(R^4-r^4\right)}$$"
        HTMLMath2.value = r"<font size = '3'; font color = 'cyan'>$$\tau_2=\frac{4\left(R^2-Rr-r^2\right)V_z}{3\pi\left(R^4-r^4\right)}$$"
        HTMLMath3.value = r"<font size = '3'; font color = 'cyan'>$$\tau_3=\frac{2R^2\left(V_y+V_z\right)}{3\pi \left(R^4-r^4\right)}$$"
        HTMLMath4.value = r"<font size = '3'; font color = 'cyan'>$$\tau_4=\frac{4\left(R^2-Rr-r^2\right)\sqrt{V_y^2+V_z^2}}{3\pi\left(R^4-r^4\right)}$$"
        HTMLs[9].value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>V1</b></font>"
        HTMLs[10].value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>V2</b></font>"
f_tipo = ipw.interactive(tipo, esfuerzo = Dropdown1)
Dropdown1.description='';

# FloatSlider1    = ipw.FloatSlider(
#     description = '',
#     value       = 1,
#     min         = 1,
#     max         = 100,
#     step        = 1,
#     readout     = False,
#     style       = {'handle_color': 'cyan'}
# )
# HBox1 = ipw.HBox([FloatSlider1, HTML2])
# def upd_html2(valor):
#     texto2 = str(valor)
#     HTML2.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto2}</b></font>"
# f_upd_html2 = ipw.interactive(upd_html2, valor = FloatSlider1)
# FloatSlider1.description = ''

FloatSlider2    = ipw.FloatSlider(
    description = '',
    value       = 1,
    min         = 1,
    max         = 100,
    step        = 1,
    readout     = False,
    style       = {'handle_color': 'cyan'}
)
HBox2 = ipw.HBox([FloatSlider2, HTML3])
def upd_html3(valor):
    texto3 = str(valor)
    HTML3.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto3}</b></font>"
f_upd_html3 = ipw.interactive(upd_html3, valor = FloatSlider2)
FloatSlider2.description = ''

FloatSlider3    = ipw.FloatSlider(
    description = '',
    value       = 1,
    min         = 1,
    max         = 100,
    step        = 1,
    readout     = False,
    style       = {'handle_color': 'cyan'}
)
HBox3 = ipw.HBox([FloatSlider3, HTML4])
def upd_html4(valor):
    texto4 = str(valor)
    HTML4.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto4}</b></font>"
f_upd_html4 = ipw.interactive(upd_html4, valor = FloatSlider3)
FloatSlider3.description = ''

FloatSlider4    = ipw.FloatSlider(
    description = '',
    value       = 1,
    min         = 1,
    max         = 100,
    step        = 1,
    readout     = False,
    style       = {'handle_color': 'cyan'},
    layout      = ipw.Layout(width='20%')
)
x = np.random.randint(1, 100, size=(100)) * 0
y = np.random.randint(1, 100, size=(100)) * 0
er = np.random.randint(1, 100, size=(100)) * 0
def upd_html5(valor):
    texto5 = str(valor)
    HTML5.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto5}</b></font>"
    FloatText1.value = x[int(valor - 1)]
    FloatText2.value = y[int(valor - 1)]
    FloatText3.value = er[int(valor - 1)]
f_upd_html5 = ipw.interactive(upd_html5, valor = FloatSlider4)
FloatSlider4.description = ''

FloatSlider5    = ipw.FloatSlider(
    description = '',
    value       = 0,
    min         = 0,
    max         = 99,
    step        = 1,
    readout     = False,
    style       = {'handle_color': 'cyan'}
)
HBox7 = ipw.HBox([FloatSlider5, HTML1])
def upd_html1(valor):
    texto6 = str(valor)
    HTML1.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto6}</b></font>"
f_upd_html1 = ipw.interactive(upd_html1, valor = FloatSlider5)
FloatSlider5.description = ''

FloatSlider6    = ipw.FloatSlider(
    description = '',
    value       = 1,
    min         = 1,
    max         = 150,
    step        = 1,
    readout     = False,
    style       = {'handle_color': 'cyan'}
)
HBox8 = ipw.HBox([FloatSlider6, HTML7])
def upd_html7(valor):
    texto8 = str(valor)
    HTML7.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto8}</b></font>"
f_upd_html7 = ipw.interactive(upd_html7, valor = FloatSlider6)
FloatSlider6.description = ''

E = 2e11
G = 77e9
rho = 7850
def esfdef(r1, R1, L1, F1, M1):
    global Ber_def
    global Tim_def
    r = r1 / 1000
    R = R1 / 1000
    L = L1 / 1000
    F = F1 * 1000
    M = M1 * 1000
    A = np.pi * (R**2 - r**2)
    I = (np.pi / 4) * (R**4 - r**4)
    Q = (4 * (R**2 - R*r + r**2)) / (3 * A * (R**2 + r**2))
    if r == 0:
        k = 0.9
    else:
        k = 0.5
    lam = (12 * E * I) / (k * A * G * L**2)
    if ToggleButton3.value == 1:
        F = F + A * L * rho * 9.81
    Lines19.labels = ['F = ' + str(round(F,2)) + ' N']
    Ber_def = (F * L ** 3) / (24 * E * I)
    Tim_def = (F * L ** 3) / (24 * E * I) * (1 + lam)
    if ToggleButton2.value == 1:
        Ber_sin = (M * R) / I
        Tim_con = np.sqrt(((M * R) / I) ** 2 + 3 * (F * Q) ** 2)
        FloatText4.value = Ber_sin
        FloatText5.value = Tim_con
        FloatText6.value = (abs(Tim_con - Ber_sin) / Tim_con) * 100
    else:
        FloatText4.value = Ber_def * 1000
        FloatText5.value = Tim_def * 1000
        FloatText6.value = (abs(Tim_def - Ber_def) / Tim_def) * 100

FloatSlider7    = ipw.FloatSlider(
    description = 'r (mm):',
    value       = 0,
    min         = 0,
    max         = 195,
    step        = 1,
    readout     = True,
    style       = {'handle_color': 'cyan'}
)
def draw1(valor):
    Lines17.x = [-FloatSlider9.value / 2, FloatSlider9.value / 2, FloatSlider9.value / 2, -FloatSlider9.value / 2, -FloatSlider9.value / 2]    
    Lines17.y = [-valor, -valor, valor, valor, -valor]
    esfdef(r1 = valor, R1 = FloatSlider8.value, L1 = FloatSlider9.value, F1 = FloatSlider10.value, M1 = FloatSlider11.value)
    Lines20.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines20.y = [-FloatSlider8.value, -FloatSlider8.value - Ber_def * 1000, -FloatSlider8.value] 
    Lines21.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines21.y = [FloatSlider8.value, FloatSlider8.value - Ber_def * 1000, FloatSlider8.value] 
    Lines22.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines22.y = [-FloatSlider8.value, -FloatSlider8.value - Tim_def * 1000, -FloatSlider8.value] 
    Lines23.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines23.y = [FloatSlider8.value, FloatSlider8.value - Tim_def * 1000, FloatSlider8.value]
f_draw1 = ipw.interactive(draw1, valor = FloatSlider7)

FloatSlider8    = ipw.FloatSlider(
    description = 'R (mm):',
    value       = 10,
    min         = 10,
    max         = 200,
    step        = 1,
    readout     = True,
    style       = {'handle_color': 'cyan'}
)
def draw2(valor):
    Lines18.x = [-FloatSlider9.value / 2, FloatSlider9.value / 2, FloatSlider9.value / 2, -FloatSlider9.value / 2, -FloatSlider9.value / 2]    
    Lines18.y = [-valor, -valor, valor, valor, -valor]
    Lines19.y = [valor, valor + 100]
    Scatter1.x = [-FloatSlider9.value/2, FloatSlider9.value/2]
    Scatter1.y = [-valor, -valor]
    Scatter2.y = [valor]
    esfdef(r1 = FloatSlider7.value, R1 = valor, L1 = FloatSlider9.value, F1 = FloatSlider10.value, M1 = FloatSlider11.value)
    Lines20.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines20.y = [-valor, -valor - Ber_def * 1000, -valor] 
    Lines21.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines21.y = [valor, valor - Ber_def * 1000, valor] 
    Lines22.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines22.y = [-valor, -valor - Tim_def * 1000, -valor] 
    Lines23.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines23.y = [valor, valor - Tim_def * 1000, valor] 
f_draw2 = ipw.interactive(draw2, valor = FloatSlider8)

FloatSlider9    = ipw.FloatSlider(
    description = 'L (mm):',
    value       = 1000,
    min         = 100,
    max         = 10000,
    step        = 100,
    readout     = True,
    style       = {'handle_color': 'cyan'}
)
def draw3(valor):
    Lines17.x = [-valor / 2, valor / 2, valor / 2, -valor / 2, -valor / 2]    
    Lines17.y = [-FloatSlider7.value, -FloatSlider7.value, FloatSlider7.value, FloatSlider7.value, -FloatSlider7.value]
    Lines18.x = [-valor / 2, valor / 2, valor / 2, -valor / 2, -valor / 2]
    Lines18.y = [-FloatSlider8.value, -FloatSlider8.value, FloatSlider8.value, FloatSlider8.value, -FloatSlider8.value]
    Scatter1.x = [-valor/2, valor/2]
    esfdef(r1 = FloatSlider7.value, R1 = FloatSlider8.value, L1 = valor, F1 = FloatSlider10.value, M1 = FloatSlider11.value)
    Lines20.x = [-valor / 2, 0, valor / 2]
    Lines20.y = [-FloatSlider8.value, -FloatSlider8.value - Ber_def * 1000, -FloatSlider8.value] 
    Lines21.x = [-valor / 2, 0, valor / 2]
    Lines21.y = [FloatSlider8.value, FloatSlider8.value - Ber_def * 1000, FloatSlider8.value] 
    Lines22.x = [-valor / 2, 0, valor / 2]
    Lines22.y = [-FloatSlider8.value, -FloatSlider8.value - Tim_def * 1000, -FloatSlider8.value] 
    Lines23.x = [-valor / 2, 0, valor / 2]
    Lines23.y = [FloatSlider8.value, FloatSlider8.value - Tim_def * 1000, FloatSlider8.value] 
f_draw3 = ipw.interactive(draw3, valor = FloatSlider9)

FloatSlider10   = ipw.FloatSlider(
    description = 'F (kN):',
    value       = 0,
    min         = 0,
    max         = 10000,
    step        = 50,
    readout     = True,
    style       = {'handle_color': 'cyan'}
)
def draw4(valor):
    esfdef(r1 = FloatSlider7.value, R1 = FloatSlider8.value, L1 = FloatSlider9.value, F1 = valor, M1 = FloatSlider11.value)
    Lines20.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines20.y = [-FloatSlider8.value, -FloatSlider8.value - Ber_def * 1000, -FloatSlider8.value] 
    Lines21.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines21.y = [FloatSlider8.value, FloatSlider8.value - Ber_def * 1000, FloatSlider8.value] 
    Lines22.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines22.y = [-FloatSlider8.value, -FloatSlider8.value - Tim_def * 1000, -FloatSlider8.value] 
    Lines23.x = [-FloatSlider9.value / 2, 0, FloatSlider9.value / 2]
    Lines23.y = [FloatSlider8.value, FloatSlider8.value - Tim_def * 1000, FloatSlider8.value]
f_draw4 = ipw.interactive(draw4, valor = FloatSlider10)

FloatSlider11   = ipw.FloatSlider(
    description = 'M (kN.m)',
    value       = 0,
    min         = 0,
    max         = 1000,
    step        = 10,
    readout     = True,
    style       = {'handle_color': 'cyan'}
)
def draw5(valor):
    esfdef(r1 = FloatSlider7.value, R1 = FloatSlider8.value, L1 = FloatSlider9.value, F1 = FloatSlider10.value, M1 = valor)
f_draw5 = ipw.interactive(draw5, valor = FloatSlider11)

ToggleButton2   = ipw.ToggleButton(
    description = 'Deflexion',
    value       = 0,
    # layout      = ipw.Layout(width='180px', height='28px', margin='15px 0px 0px 0px', border='0px', padding='0px'),
    button_style= 'warning'
)
def upd_tgbt2(valor):
    if valor == 1:
        ToggleButton2.description = 'Esfuerzo'
        FloatText4.description = 'Bern. (Pa)'
        FloatText5.description = 'Timo. (Pa)'
        button_style= 'primary'
    else:
        ToggleButton2.description = 'Deflexion'
        FloatText4.description = 'Bern. (mm)'
        FloatText5.description = 'Timo. (mm)'
        button_style= 'warning'
f_upd_tgbt2 = ipw.interactive(upd_tgbt2, valor = ToggleButton2)

ToggleButton3   = ipw.ToggleButton(
    description = 'No incluye peso',
    value       = 0,
    # layout      = ipw.Layout(width='180px', height='28px', margin='15px 0px 0px 0px', border='0px', padding='0px'),
    button_style= 'warning'
)
def upd_tgbt3(valor):
    if valor == 1:
        ToggleButton3.description = 'Incluye peso'
        button_style= 'primary'
    else:
        ToggleButton3.description = 'No incluye peso'
        button_style= 'warning'
f_upd_tgbt3 = ipw.interactive(upd_tgbt3, valor = ToggleButton3)

HBox11 = ipw.HBox([ToggleButton2, ToggleButton3])

FloatText4 = ipw.FloatText(
    description = 'Bern. (mm)',
    value       = 0,
    disabled    = True,
    # layout      = ipw.Layout(width='10%')
)

FloatText5 = ipw.FloatText(
    description = 'Timo. (mm)',
    value       = 0,
    disabled    = True,
    # layout      = ipw.Layout(width='10%')
)

FloatText6 = ipw.FloatText(
    description = '% de error',
    value       = 0,
    disabled    = True,
    # layout      = ipw.Layout(width='10%')
)

VBox4 = ipw.VBox([HTMLs[15], FloatSlider7, FloatSlider8, FloatSlider9, FloatSlider10, FloatSlider11, HBox11, FloatText4, FloatText5, FloatText6] 
    # layout      = ipw.Layout(height='350px', width='25%', align_items = 'stretch')
)

FloatText1 = ipw.FloatText(
    description = '',
    value       = 1,
    disabled    = False,
    layout      = ipw.Layout(width='10%')
)
FloatText2 = ipw.FloatText(
    description = '',
    value       = 1,
    disabled    = False,
    layout      = ipw.Layout(width='10%')
)
FloatText3 = ipw.FloatText(
    description = '',
    value       = 1,
    disabled    = True,
    layout      = ipw.Layout(width='10%')
)
HBox6 = ipw.HBox([HTMLs[8], FloatSlider4, HTML5, HTML6, HTMLs[9], FloatText1, HTMLs[10], FloatText2, HTMLs[11], FloatText3], 
    layout      = ipw.Layout(justify_content = 'space-between')
)

ToggleButton1   = ipw.ToggleButton(
    description = 'R/r >= √2',
    value       = 0,
    layout      = ipw.Layout(width='180px', height='28px', margin='15px 0px 0px 0px', border='0px', padding='0px'),
    button_style= 'warning'
)

def upd_tgbt(valor):
    if Dropdown1.value == 'Esfuerzos cortantes':
        if valor == 1:
            ToggleButton1.description = 'R/r < √2'
            ToggleButton1.button_style = 'primary'
            HTMLMath3.value = r"<font size = '3'; font color = 'cyan'>$$\tau_3=\frac{\left(R+r\right)\left(V_y+V_z\right)}{\pi\left(R^2+r^2\right)\left(R-\sqrt{2r^2-R^2}\right)}$$"
        else:
            ToggleButton1.description = 'R/r >= √2'
            ToggleButton1.button_style = 'warning'
            HTMLMath3.value = r"<font size = '3'; font color = 'cyan'>$$\tau_3=\frac{2R^2\left(V_y+V_z\right)}{3\pi \left(R^4-r^4\right)}$$"
f_upd_tgbt = ipw.interactive(upd_tgbt, valor = ToggleButton1)

HBox5 = ipw.HBox([Dropdown1, ToggleButton1])
# VBox1 = ipw.VBox([HTMLs[0], HBox5, HTMLs[1], HTMLMath1, HTMLs[2], HTMLMath2, HTMLs[3], HTMLMath3, HTMLs[4], HTMLMath4, HTMLs[6], HBox2, HTMLs[5], HBox1, HTMLs[7], HBox3, HTMLs[12], HBox7], 
VBox1 = ipw.VBox([HTMLs[0], HBox5, HTMLs[1], HTMLMath1, HTMLs[2], HTMLMath2, HTMLs[3], HTMLMath3, HTMLs[4], HTMLMath4, HTMLs[6], HBox2, HTMLs[7], HBox3, HTMLs[12], HBox7], 
        layout = ipw.Layout(border='0px', padding='0px', width='25%', height='auto')
)

scale_x1 = bq.LinearScale(min = 0, max = 100)
scale_y1 = bq.LinearScale(min = 0, max = 100)
Lines1  = bq.Lines(x = np.arange(1,101), y = np.random.rand(1, 100),
                   scales = {'x': scale_x1, 'y': scale_y1,},
                   labels=['Formula 1'],
                   display_legend=True,
                   colors = ['red'],
                   opacities = [1],
                   stroke_width = 1.5
)
Lines2  = bq.Lines(x = np.arange(1,101), y = np.random.rand(1, 100),
                   scales = {'x': scale_x1, 'y': scale_y1,},
                   labels=['Formula 2'],
                   display_legend=True,
                   colors = ['green'],
                   opacities = [1],
                   stroke_width = 1.5
)
Lines3  = bq.Lines(x = np.arange(1,101), y = np.random.rand(1, 100),
                   scales = {'x': scale_x1, 'y': scale_y1,},
                   labels=['Formula 3'],
                   display_legend=True,
                   colors = ['black'],
                   opacities = [1],
                   stroke_width = 1.5
)
Lines4  = bq.Lines(x = np.arange(1,101), y = np.random.rand(1, 100),
                   scales = {'x': scale_x1, 'y': scale_y1,},
                   labels=['Formula 4'],
                   display_legend=True,
                   colors = ['blue'],
                   opacities = [0.5],
                   stroke_width = 1.5
)

scale_y11 = bq.LinearScale(min = 0, max = 60)
Lines5  = bq.Lines(x = np.arange(1,101), y = np.random.rand(1, 100),
                   scales = {'x': scale_x1, 'y': scale_y11,},
                   labels=['% Error'],
                   display_legend=True,
                   colors = ['yellow'],
                   opacities = [0.5],
                   stroke_width = 1.5,
                   interpolation = 'basis'
)

scale_x2 = bq.LinearScale(min = 0, max = 100)
scale_y2 = bq.LinearScale(min = 0, max = 10)
Lines6  = bq.Lines(x = np.arange(1,101), y = np.zeros((1,100)),
                   scales = {'x': scale_x2, 'y': scale_y2,},
                   labels=['Esfuerzos Flexionantes'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['magenta'],
                   interpolation = 'basis'
)

scale_y22 = bq.LinearScale(min = 0, max = 60)
Lines7  = bq.Lines(x = np.arange(1,101), y = np.zeros((1,100)),
                   scales = {'x': scale_x2, 'y': scale_y22,},
                   labels=['Esfuerzos Cortantes'],
                   display_legend=True,
                   opacities = [0.8],
                   colors = ['orange'],
                   interpolation = 'basis'
)

scale_x3 = bq.LinearScale(min = -100, max = 100)
scale_y3 = bq.LinearScale(min = -100, max = 100)

tetha = np.linspace(0,2*np.pi,50)
Lines8  = bq.Lines(x = FloatSlider5.value * np.cos(tetha), y = FloatSlider5.value * np.sin(tetha),
                   scales = {'x': scale_x3, 'y': scale_y3,},
#                    labels=['Circulo menor'],
#                    display_legend=True,
                   opacities = [1],
                   colors = ['black'],
                   interpolation = 'basis'
)
Lines9  = bq.Lines(x = FloatSlider3.value * np.cos(tetha), y = FloatSlider3.value * np.sin(tetha),
                   scales = {'x': scale_x3, 'y': scale_y3,},
#                    labels=['Circulo mayor'],
#                    display_legend=True,
                   opacities = [1],
                   colors = ['black'],
                   interpolation = 'basis'
)

scale_x4 = bq.LinearScale(min = 0, max = 100)
scale_y4 = bq.LinearScale(min = 0, max = 100)

Lines10  = bq.Lines(x = np.arange(1,101), y = np.zeros((1,100)),
                   scales = {'x': scale_x4, 'y': scale_y4,},
                   labels=['Esfuerzo Cortante Macizo'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['blue'],
                   interpolation = 'basis'
)
Lines11  = bq.Lines(x = np.arange(1,101), y = np.zeros((1,100)),
                   scales = {'x': scale_x4, 'y': scale_y4,},
                   labels=['Esfuerzo Cortante Hueco'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['red'],
                   interpolation = 'basis'
)
Lines12  = bq.Lines(x = [0, 0], y = [0, 100],
                   scales = {'x': scale_x4, 'y': scale_y4,},
                   labels=['R/r =   y R/rr= '],
                   display_legend=True,
                   opacities = [1],
                   colors = ['green'],
)

scale_x5 = bq.LinearScale(min = 0, max = 150)
scale_y5 = bq.LinearScale(min = 0, max = 100)

Lines13  = bq.Lines(x = np.arange(1,151), y = np.zeros((1,151)),
                   scales = {'x': scale_x5, 'y': scale_y5,},
                   labels=['Principal cortante'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['blue'],
                   stroke_width = 3.0,
                   interpolation = 'basis'
)
Lines14  = bq.Lines(x = np.arange(1,151), y = np.zeros((1,151)),
                   scales = {'x': scale_x5, 'y': scale_y5,},
                   labels=['Principal normal'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['red'],
                   stroke_width = 2.5,
                   interpolation = 'basis'
)
Lines15  = bq.Lines(x = np.arange(1,151), y = np.zeros((1,151)),
                   scales = {'x': scale_x5, 'y': scale_y5,},
                   labels=['Tresca'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['green'],
                   stroke_width = 2.0,
                   interpolation = 'basis'
                    
)

Lines16  = bq.Lines(x = np.arange(1,151), y = np.zeros((1,151)),
                   scales = {'x': scale_x5, 'y': scale_y5,},
                   labels=['Von misses'],
                   display_legend=True,
                   opacities = [1],
                   colors = ['black'],
                   stroke_width = 1.5,
                   interpolation = 'basis'
)

scale_x6 = bq.LinearScale(min = -3000, max = 3000)
scale_y6 = bq.LinearScale(min = -300, max = 300)

Lines17  = bq.Lines(x = [-FloatSlider9.value/2, FloatSlider9.value/2, FloatSlider9.value/2, -FloatSlider9.value/2, -FloatSlider9.value/2], y = [-FloatSlider7.value, -FloatSlider7.value, FloatSlider7.value, FloatSlider7.value, -FloatSlider7.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [1],
                   colors = ['black'],
                   stroke_width = 1.5,
                   line_style = 'dashed'
)

Lines18  = bq.Lines(x = [-FloatSlider9.value/2, FloatSlider9.value/2, FloatSlider9.value/2, -FloatSlider9.value/2, -FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value, FloatSlider8.value, FloatSlider8.value, -FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [1],
                   colors = ['black'],
                   stroke_width = 1.5
)

Lines19  = bq.Lines(x = [0, 0], y = [FloatSlider8.value, FloatSlider8.value + 100],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [1],
                   colors = ['black'],
                   labels=['F: 0 N'],
                   display_legend=True,
                   stroke_width = 1.5
)

Lines20  = bq.Lines(x = [-FloatSlider9.value/2, 0, FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value, -FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [0.5],
                   labels=['Bernoulli'],
                   display_legend=True,
                   colors = ['red'],
                   stroke_width = 1.5,
                   interpolation = 'basis' 
)

Lines21  = bq.Lines(x = [-FloatSlider9.value/2, 0, FloatSlider9.value/2], y = [FloatSlider8.value, FloatSlider8.value, FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [0.5],
                   colors = ['red'],
                   stroke_width = 1.5,
                   interpolation = 'basis' 
)

Lines22  = bq.Lines(x = [-FloatSlider9.value/2, 0, FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value, -FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [0.5],
                   labels=['Timoshenko'],
                   display_legend=True,
                   colors = ['blue'],
                   stroke_width = 1.5,
                   interpolation = 'basis' 
)

Lines23  = bq.Lines(x = [-FloatSlider9.value/2, 0, FloatSlider9.value/2], y = [FloatSlider8.value, FloatSlider8.value, FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [0.5],
                   colors = ['blue'],
                   stroke_width = 1.5,
                   interpolation = 'basis' 
)

Scatter1 = bq.Scatter(x = [-FloatSlider9.value/2, FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [1],
                   colors = ['black'],
                   marker='triangle-up'
)

Scatter2 = bq.Scatter(x = [0], y = [FloatSlider8.value],
                   scales = {'x': scale_x6, 'y': scale_y6,},
                   opacities = [1],
                   colors = ['black'],
                   marker='triangle-down' 
)

ax_x1   = bq.Axis(scale = scale_x1, label = 'Ensayo', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan')
ax_y1   = bq.Axis(scale = scale_y1, label = 'Magnitud del Esfuerzo', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan', orientation = 'vertical')
ax_y11  = bq.Axis(scale = scale_y11, label = '% Error', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan', orientation = 'vertical', side='right')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x1], 'y': [scale_y1]})
fig1    = bplt.figure(title='Comparacion de formulas: Error disperso', title_style={'font-size': '20px','fill': 'cyan'}, marks = [Lines1, Lines2, Lines3, Lines4, Lines5], axes = [ax_x1, ax_y1, ax_y11], fig_margin = m_fig, layout=ipw.Layout(width='auto', height='50%'))
# fig1.background_style = {'fill': 'Black'}
fig1.interaction = panzoom

ax_x2   = bq.Axis(scale = scale_x2, label = 'Relacion', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan')
ax_y2   = bq.Axis(scale = scale_y2, label = '% de Error: Flexionantes', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan', orientation = 'vertical')
ax_y22  = bq.Axis(scale = scale_y22, label = '% de Error: Cortantes', label_color = 'cyan', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'cyan'}, color='cyan', orientation = 'vertical', side='right')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x2], 'y': [scale_y22]})
fig2    = bplt.figure(title='Comparacion de formulas: Error maximo', title_style={'font-size': '20px','fill': 'cyan'}, marks = [Lines6, Lines7], axes = [ax_x2, ax_y2, ax_y22], fig_margin = m_fig, layout=ipw.Layout(width='auto', height='50%'))
# fig2.background_style = {'fill': 'Black'}
fig2.interaction = panzoom

ax_x3   = bq.Axis(scale = scale_x3, label = 'X', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black')
ax_y3   = bq.Axis(scale = scale_y3, label = 'Y', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black', orientation = 'vertical')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x3], 'y': [scale_y3]})
fig3    = bplt.figure(title='Seccion del eje', title_style={'font-size': '20px','fill': 'black'}, marks = [Lines8, Lines9], axes = [ax_x3, ax_y3], fig_margin = m_fig, layout=ipw.Layout(width='25%', height='auto'))
fig3.interaction = panzoom
fig3.max_aspect_ratio = 1
fig3.min_aspect_ratio = 1

ax_x4   = bq.Axis(scale = scale_x4, label = 'Radio interior del eje hueco', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black')
ax_y4   = bq.Axis(scale = scale_y4, label = 'Esfuerzo cortante', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black', orientation = 'vertical')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x4], 'y': [scale_y4]})
fig4    = bplt.figure(title='Variacion del esfuerzo cortante en funcion al radio interno', title_style={'font-size': '20px','fill': 'black'}, marks = [Lines10, Lines11, Lines12], axes = [ax_x4, ax_y4], fig_margin = m_fig, layout=ipw.Layout(width='75%', height='auto'))
fig4.interaction = panzoom

ax_x5   = bq.Axis(scale = scale_x5, label = 'Relacion', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black')
ax_y5   = bq.Axis(scale = scale_y5, label = '% de Error', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black', orientation = 'vertical')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x5], 'y': [scale_y5]})
fig5    = bplt.figure(title='% de error en funcion a la relacion τ1 / τ2', title_style={'font-size': '20px','fill': 'black'}, marks = [Lines13, Lines14, Lines15, Lines16], axes = [ax_x5, ax_y5], fig_margin = m_fig, layout=ipw.Layout(width='75%', height='auto'))
fig5.interaction = panzoom

ax_x6   = bq.Axis(scale = scale_x6, label = 'Longitud (mm)', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black')
ax_y6   = bq.Axis(scale = scale_y6, label = 'Diametro (mm)', label_color = 'black', label_offset = '-2em', grid_lines = 'none', tick_format = '0.0f', tick_style = {'stroke': 'black'}, color='black', orientation = 'vertical')
m_fig   = dict(left=50, top=20, bottom=30, right=30)
panzoom = bq.interacts.PanZoom(scales={'x': [scale_x6], 'y': [scale_y6]})
fig6    = bplt.figure(title='Esquema del eje a analizar', title_style={'font-size': '20px','fill': 'black'}, marks = [Lines17, Lines18, Lines19, Lines20, Lines21, Lines22, Lines23, Scatter1, Scatter2], axes = [ax_x6, ax_y6], fig_margin = m_fig, layout=ipw.Layout(width='75%', height='auto'))
fig6.interaction = panzoom

HBox10 = ipw.HBox([VBox4, fig6], 
         layout = ipw.Layout(height='350px', justify_content = 'space-between')
)

VBox3 = ipw.VBox([HTMLs[13], HTMLMath5, HTMLMath6, HTMLMath7, HTMLMath8, HTMLs[14], HBox8],
        layout = ipw.Layout(width='25%', height='auto', justify_content = 'flex-start', align_items = 'stretch')
)

HBox9 = ipw.HBox([VBox3, fig5], 
        layout = ipw.Layout(height='425px', justify_content = 'space-between')
)

HBox7 = ipw.HBox([fig3, fig4], 
        layout = ipw.Layout(height='300px', justify_content = 'space-between')
)

VBox2 = ipw.VBox([fig1, fig2],
        layout = ipw.Layout(margin = '0px', border='0px', padding='0px', width='75%', height='auto', justify_content = 'flex-end', align_items = 'stretch')
)
HBox4 = ipw.HBox([VBox1, VBox2])  

# Lines6_d = Lines6.y
# def flex_1(valor):
#     global x
#     global y
#     global er
#     z = np.random.randint(1000, 10000, size=(100))
#     x = z * FloatSlider2.value
#     y = z 
#     if Dropdown1.value == 'Esfuerzos flexionantes':
#         f1 = (FloatSlider3.value / valor) * x
#         f2 = (FloatSlider3.value / valor) * y
#         f3 = (FloatSlider3.value / valor) * ((x + y) / np.sqrt(2))
#         f4 = (FloatSlider3.value / valor) * np.sqrt(x ** 2 + y ** 2)
#     elif Dropdown1.value == 'Esfuerzos cortantes':
#         if FloatSlider5.value < FloatSlider3.value:
#             f1 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2) * x)
#             f2 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2) * y)
#             if FloatSlider5.value <= FloatSlider3.value / np.sqrt(2):
#                 f3 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (FloatSlider3.value ** 2 * (x + y))
#             else:
#                 f3 = ((2 * np.sqrt(2) * 0.3535 * (FloatSlider3.value + FloatSlider5.value)) / (np.pi * (FloatSlider3.value ** 2 + FloatSlider5.value ** 2) * (FloatSlider3.value - np.sqrt(abs(2 * FloatSlider5.value ** 2 - FloatSlider3.value ** 2))))) * (x + y)
#             f4 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2)) * np.sqrt((x ** 2 + y ** 2))
#         else:
#             f1 = np.random.randint(1, 100, size=(100)) * 0 + 1
#             f2 = np.random.randint(1, 100, size=(100)) * 0 + 1
#             f3 = np.random.randint(1, 100, size=(100)) * 0 + 1
#             f4 = np.random.randint(1, 100, size=(100)) * 0 + 1
#     mf = np.amax([f1, f2, f3], axis=0)
#     er = abs((f4 - mf) / mf) * 100;
#     ep = np.amax(er)
#     Lines1.y = f1
#     Lines2.y = f2
#     Lines3.y = f3
#     Lines4.y = f4
#     Lines5.y = er
#     if Dropdown1.value == 'Esfuerzos flexionantes':
#         Lines6_d[int(FloatSlider2.value - 1)] = ep
#         Lines6.y = Lines6_d + 0
#     elif Dropdown1.value == 'Esfuerzos cortantes':
#         Lines7_d[int(FloatSlider2.value - 1)] = ep
#         Lines7.y = Lines7_d + 0
#     Lines4.scales['y'].max = np.amax([f1, f2, f3, f4]) * 1.1
# f_flex_1 = ipw.interactive(flex_1, valor = FloatSlider1)
# FloatSlider1.description = ''

Lines6_d = Lines6.y
Lines7_d = Lines7.y
def flex_2(valor):
    global x
    global y
    global er
    I = (np.pi / 4) * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4)
    z = np.random.randint(1000, 10000, size=(100))
    x = z * valor
    y = z 
    if Dropdown1.value == 'Esfuerzos flexionantes':
        f1 = (FloatSlider3.value / I) * x
        f2 = (FloatSlider3.value / I) * y
        f3 = (FloatSlider3.value / I) * (x + y) / np.sqrt(2)
        f4 = (FloatSlider3.value / I) * np.sqrt(x ** 2 + y ** 2)
    elif Dropdown1.value == 'Esfuerzos cortantes':
        if FloatSlider5.value < FloatSlider3.value:
            f1 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2) * x)
            f2 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2) * y)
            if FloatSlider5.value <= FloatSlider3.value / np.sqrt(2):
                f3 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (FloatSlider3.value ** 2 * (x + y))
            else:
                f3 = ((2 * np.sqrt(2) * 0.3535 * (FloatSlider3.value + FloatSlider5.value)) / (np.pi * (FloatSlider3.value ** 2 + FloatSlider5.value ** 2) * (FloatSlider3.value - np.sqrt(abs(2 * FloatSlider5.value ** 2 - FloatSlider3.value ** 2))))) * (x + y)
            f4 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2)) * np.sqrt((x ** 2 + y ** 2))
        else:
            f1 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f2 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f3 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f4 = np.random.randint(1, 100, size=(100)) * 0 + 1
    mf = np.amax([f1, f2, f3], axis=0)
    er = abs((f4 - mf) / mf) * 100;
    ep = np.amax(er)
    Lines1.y = f1
    Lines2.y = f2
    Lines3.y = f3
    Lines4.y = f4
    Lines5.y = er
    if Dropdown1.value == 'Esfuerzos flexionantes':
        Lines6_d[int(valor - 1)] = ep
        Lines6.y = Lines6_d + 0
    elif Dropdown1.value == 'Esfuerzos cortantes':
        Lines7_d[int(valor - 1)] = ep
        Lines7.y = Lines7_d + 0
    Lines4.scales['y'].max = np.amax([f1, f2, f3, f4]) * 1.1
f_flex_2 = ipw.interactive(flex_2, valor = FloatSlider2)
FloatSlider2.description = ''

Lines11_d = Lines11.y
def flex_3(valor):
    global x
    global y
    global er
    I = (np.pi / 4) * (valor ** 4 - FloatSlider5.value ** 4)
    z = np.random.randint(1000, 10000, size=(100))
    x = z * FloatSlider2.value
    y = z 
    if FloatSlider5.value != 0:
        texto7 = 'R/r = ' + str(round(valor / FloatSlider5.value, 2))
        HTML6.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto7}</b></font>"
        if valor / FloatSlider5.value >= np.sqrt(2):
            ToggleButton1.value = 0
        elif valor / FloatSlider5.value < np.sqrt(2):
            ToggleButton1.value = 1
    else:
        HTML6.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>R/r = ∞</b></font>"
        ToggleButton1.value = 0
    if Dropdown1.value == 'Esfuerzos flexionantes':
        f1 = (FloatSlider3.value / I) * x
        f2 = (FloatSlider3.value / I) * y
        f3 = (FloatSlider3.value / I) * ((x + y) / np.sqrt(2))
        f4 = (FloatSlider3.value / I) * np.sqrt(x ** 2 + y ** 2)
    elif Dropdown1.value == 'Esfuerzos cortantes':
        if FloatSlider5.value < valor:
            f1 = (2 / (3 * np.pi * (valor ** 4 - FloatSlider5.value ** 4))) * (2 * (valor ** 2 - valor * FloatSlider5.value + FloatSlider5.value ** 2) * x)
            f2 = (2 / (3 * np.pi * (valor ** 4 - FloatSlider5.value ** 4))) * (2 * (valor ** 2 - valor * FloatSlider5.value + FloatSlider5.value ** 2) * y)
            if FloatSlider5.value <= valor / np.sqrt(2):
                f3 = (2 / (3 * np.pi * (valor ** 4 - FloatSlider5.value ** 4))) * (valor ** 2 * (x + y))
            else:
                f3 = ((2 * np.sqrt(2) * 0.3535 * (valor + FloatSlider5.value)) / (np.pi * (valor ** 2 + FloatSlider5.value ** 2) * (valor - np.sqrt(abs(2 * FloatSlider5.value ** 2 - valor ** 2))))) * (x + y)
            f4 = (2 / (3 * np.pi * (valor ** 4 - FloatSlider5.value ** 4))) * (2 * (valor ** 2 - valor * FloatSlider5.value + FloatSlider5.value ** 2)) * np.sqrt((x ** 2 + y ** 2))
        else:
            f1 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f2 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f3 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f4 = np.random.randint(1, 100, size=(100)) * 0 + 1
    mf = np.amax([f1, f2, f3], axis=0)
    er = abs((f4 - mf) / mf) * 100;
    ep = np.amax(er)
    Lines1.y = f1
    Lines2.y = f2
    Lines3.y = f3
    Lines4.y = f4
    Lines5.y = er
    if Dropdown1.value == 'Esfuerzos flexionantes':
        Lines6_d[int(FloatSlider2.value - 1)] = ep
        Lines6.y = Lines6_d + 0
    elif Dropdown1.value == 'Esfuerzos cortantes':
        Lines7_d[int(FloatSlider2.value - 1)] = ep
        Lines7.y = Lines7_d + 0
    Lines4.scales['y'].max = np.amax([f1, f2, f3, f4]) * 1.1
    
    Lines9.x = valor * np.cos(tetha)
    Lines9.y = valor * np.sin(tetha)
    VM = (2 / (3 * np.pi * (valor ** 4 - 0))) * (2 * (valor ** 2 - valor * 0 + 0 ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
    Lines10.y = np.zeros((1,100)) + VM
    if valor > FloatSlider5.value:
        VH = (2 / (3 * np.pi * (valor ** 4 - FloatSlider5.value ** 4))) * (2 * (valor ** 2 - valor * FloatSlider5.value + FloatSlider5.value ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
        Lines11_d[int(FloatSlider5.value)] = VH
        Lines11.y = Lines11_d + 0
    else:
        Lines11_d[int(FloatSlider5.value)::] = (2 / (3 * np.pi * (valor ** 4 - (valor - 1) ** 4))) * (2 * (valor ** 2 - valor * (valor - 1) + (valor - 1) ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
        Lines11.y = Lines11_d + 0
    Lines11.scales['y'].max = np.amax([Lines11.y]) * 1.1
    Lines11.scales['y'].min = np.amin([Lines11.y]) * 0.9
    rr = np.where(Lines11.y > Lines10.y)[0][0] - 1
    Lines12.x = [rr, rr]
    Lines12.y = [np.amin([Lines11.y]) * 0.9 , np.amax([Lines11.y]) * 1.1]
    Lines12.labels = ['rr = ' + str(round(rr, 2)) + ' y R/rr= ' + str(round(valor / rr, 2))]
f_flex_3 = ipw.interactive(flex_3, valor = FloatSlider3)
FloatSlider3.description = ''

def flex_5(valor):
    global x
    global y
    global er
    I = (np.pi / 4) * (FloatSlider3.value ** 4 - valor ** 4)
    z = np.random.randint(1000, 10000, size=(100))
    x = z * FloatSlider2.value
    y = z 
    if valor != 0:
        texto7 = 'R/r = ' + str(round(FloatSlider3.value / valor, 2))
        HTML6.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>{texto7}</b></font>"
        if FloatSlider3.value / valor >= np.sqrt(2):
            ToggleButton1.value = 0
        elif FloatSlider3.value / valor < np.sqrt(2):
            ToggleButton1.value = 1
    else:
        HTML6.value = f"<font size = '3'; font color = 'cyan'; font face = 'Courier New'><b>R/r = ∞</b></font>"
        ToggleButton1.value = 0
    if Dropdown1.value == 'Esfuerzos flexionantes':
        f1 = (FloatSlider3.value / I) * x
        f2 = (FloatSlider3.value / I) * y
        f3 = (FloatSlider3.value / I) * ((x + y) / np.sqrt(2))
        f4 = (FloatSlider3.value / I) * np.sqrt(x ** 2 + y ** 2)
    elif Dropdown1.value == 'Esfuerzos cortantes':
        if valor < FloatSlider3.value:
            f1 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - valor ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * valor + valor ** 2) * x)
            f2 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - valor ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * valor + valor ** 2) * y)
            if valor <= FloatSlider3.value / np.sqrt(2):
                f3 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - valor ** 4))) * (FloatSlider3.value ** 2 * (x + y))
            else:
                f3 = ((2 * np.sqrt(2) * 0.3535 * (FloatSlider3.value + valor)) / (np.pi * (FloatSlider3.value ** 2 + valor ** 2) * (FloatSlider3.value - np.sqrt(abs(2 * valor ** 2 - FloatSlider3.value ** 2))))) * (x + y)
            f4 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - valor ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * valor + valor ** 2)) * np.sqrt((x ** 2 + y ** 2))
        else:
            f1 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f2 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f3 = np.random.randint(1, 100, size=(100)) * 0 + 1
            f4 = np.random.randint(1, 100, size=(100)) * 0 + 1
    mf = np.amax([f1, f2, f3], axis=0)
    er = abs((f4 - mf) / mf) * 100;
    ep = np.amax(er)
    Lines1.y = f1
    Lines2.y = f2
    Lines3.y = f3
    Lines4.y = f4
    Lines5.y = er
    if Dropdown1.value == 'Esfuerzos flexionantes':
        Lines6_d[int(FloatSlider2.value - 1)] = ep
        Lines6.y = Lines6_d + 0
    elif Dropdown1.value == 'Esfuerzos cortantes':
        Lines7_d[int(FloatSlider2.value - 1)] = ep
        Lines7.y = Lines7_d + 0
    Lines4.scales['y'].max = np.amax([f1, f2, f3, f4]) * 1.1
    
    Lines8.x = valor * np.cos(tetha)
    Lines8.y = valor * np.sin(tetha)
    VM = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - 0))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * 0 + 0 ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
    Lines10.y = np.zeros((1,100)) + VM
    if FloatSlider3.value > valor:
        VH = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - valor ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * valor + valor ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
        Lines11_d[int(valor)] = VH
        Lines11.y = Lines11_d + 0
    else:
        Lines11_d[int(valor)::] = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - (FloatSlider3.value - 1) ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * (FloatSlider3.value - 1) + (FloatSlider3.value - 1) ** 2)) * np.sqrt((FloatText1.value ** 2 + FloatText2.value ** 2))
        Lines11.y = Lines11_d + 0
    Lines11.scales['y'].max = np.amax([Lines11.y]) * 1.1
    Lines11.scales['y'].min = np.amin([Lines11.y]) * 0.9 
    rr = np.where(Lines11.y > Lines10.y)[0][0] - 1
    Lines12.x = [rr, rr]
    Lines12.y = [np.amin([Lines11.y]) * 0.9 , np.amax([Lines11.y]) * 1.1]
    Lines12.labels = ['rr = ' + str(round(rr, 2)) + ' y R/rr= ' + str(round(FloatSlider3.value / rr, 2))]
f_flex_5 = ipw.interactive(flex_5, valor = FloatSlider5)
FloatSlider5.description = ''

Lines13_d = Lines13.y
Lines14_d = Lines14.y
Lines15_d = Lines15.y
Lines16_d = Lines16.y
def flex_6(valor):
    I = (np.pi / 4) * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4)
    z = np.random.randint(1000, 100000, size=(100))
    x = z * FloatSlider2.value
    y = z 
#     x = np.random.randint(1000, 100000, size=(100))
#     y = np.random.randint(1000, 100000, size=(100))
    e1 = (FloatSlider3.value / I) * np.sqrt(x ** 2 + y ** 2)      
    t2 = (2 / (3 * np.pi * (FloatSlider3.value ** 4 - FloatSlider5.value ** 4))) * (2 * (FloatSlider3.value ** 2 - FloatSlider3.value * FloatSlider5.value + FloatSlider5.value ** 2)) * np.sqrt((x ** 2 + y ** 2))
#     e1 = x
#     t1 = y
    t1 = t2 * valor   
    f11 = np.sqrt((e1 / 2) ** 2 + (t1 + t2) ** 2)
    f12 = np.sqrt((e1 / 2) ** 2 + (t1 - t2) ** 2)
    er1 = np.amax(abs((f11 - f12) / f12) * 100)
    f21 = (e1 / 2) + np.sqrt((e1 / 2) ** 2 + (t1 + t2) ** 2)
    f22 = (e1 / 2) + np.sqrt((e1 / 2) ** 2 + (t1 - t2) ** 2)
    er2 = np.amax(abs((f21 - f22) / f22) * 100)
    f31 = np.sqrt(e1 ** 2 + 4 * (t1 + t2) ** 2)
    f32 = np.sqrt(e1 ** 2 + 4 * (t1 - t2) ** 2)
    er3 = np.amax(abs((f31 - f32) / f32) * 100)
    f41 = np.sqrt(e1 ** 2 + 3 * (t1 + t2) ** 2)
    f42 = np.sqrt(e1 ** 2 + 3 * (t1 - t2) ** 2)
    er4 = np.amax(abs((f41 - f42) / f42) * 100)
    Lines13_d[int(valor - 1)] = er1
    Lines13.y = Lines13_d + 0
    Lines14_d[int(valor - 1)] = er2
    Lines14.y = Lines14_d + 0
    Lines15_d[int(valor - 1)] = er3
    Lines15.y = Lines15_d + 0
    Lines16_d[int(valor - 1)] = er4
    Lines16.y = Lines16_d + 0
f_flex_6 = ipw.interactive(flex_6, valor = FloatSlider6)
FloatSlider6.description = ''

display(HBox4)
display(HBox6)
display(HBox7)
display(HBox9)
display(HBox10)
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Input In [4], in <cell line: 492>()
#     478 Lines18  = bq.Lines(x = [-FloatSlider9.value/2, FloatSlider9.value/2, FloatSlider9.value/2, -FloatSlider9.value/2, -FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value, FloatSlider8.value, FloatSlider8.value, -FloatSlider8.value],
#     479                    scales = {'x': scale_x6, 'y': scale_y6,},
#     480                    opacities = [1],
#     481                    colors = ['black'],
#     482                    stroke_width = 1.5
#     483 )
#     485 Lines19  = bq.Lines(x = [0, 0], y = [FloatSlider8.value, FloatSlider8.value + 100],
#     486                    scales = {'x': scale_x6, 'y': scale_y6,},
#     487                    opacities = [1],
#     488                    colors = ['black'],
#     489                    stroke_width = 1.5
#     490 )
# --> 492 Scatter1 = bq.Scatter(x = [-FloatSlider9.value/2, FloatSlider9.value/2], y = [-FloatSlider8.value, -FloatSlider8.value],
#     493                    scales = {'x': scale_x6, 'y': scale_y6,},
#     494                    opacities = [1],
#     495                    colors = ['black'],
#     496                    marker=['triangle-up']
#     497 )
#     499 Scatter2 = bq.Scatter(x = [0], y = [FloatSlider8.value],
#     500                    scales = {'x': scale_x6, 'y': scale_y6,},
#     501                    opacities = [1],
#     502                    colors = ['black'],
#     503                    marker=['arrow']
#     504 )
#     506 scale_x7 = bq.LinearScale(min = 0, max = 100)
#
# File D:\Programs\Anaconda\lib\site-packages\bqplot\marks.py:547, in _ScatterBase.__init__(self, **kwargs)
#     545 self._drag_handlers = CallbackDispatcher()
#     546 self._drag_end_handlers = CallbackDispatcher()
# --> 547 super(_ScatterBase, self).__init__(**kwargs)
#     549 self._name_to_handler.update({
#     550     'drag_start': self._drag_start_handlers,
#     551     'drag_end': self._drag_end_handlers,
#     552     'drag': self._drag_handlers
#     553 })
#
# File D:\Programs\Anaconda\lib\site-packages\bqplot\marks.py:242, in Mark.__init__(self, **kwargs)
#     241 def __init__(self, **kwargs):
# --> 242     super(Mark, self).__init__(**kwargs)
#     243     self._hover_handlers = CallbackDispatcher()
#     244     self._click_handlers = CallbackDispatcher()
#
# File D:\Programs\Anaconda\lib\site-packages\ipywidgets\widgets\widget.py:412, in Widget.__init__(self, **kwargs)
#     410 """Public constructor"""
#     411 self._model_id = kwargs.pop('model_id', None)
# --> 412 super(Widget, self).__init__(**kwargs)
#     414 Widget._call_widget_constructed(self)
#     415 self.open()
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:1079, in HasTraits.__init__(self, *args, **kwargs)
#    1077 for key, value in kwargs.items():
#    1078     if self.has_trait(key):
# -> 1079         setattr(self, key, value)
#    1080     else:
#    1081         # passthrough args that don't set traits to super
#    1082         super_kwargs[key] = value
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:606, in TraitType.__set__(self, obj, value)
#     604     raise TraitError('The "%s" trait is read-only.' % self.name)
#     605 else:
# --> 606     self.set(obj, value)
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:580, in TraitType.set(self, obj, value)
#     579 def set(self, obj, value):
# --> 580     new_value = self._validate(obj, value)
#     581     try:
#     582         old_value = obj._trait_values[self.name]
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:612, in TraitType._validate(self, obj, value)
#     610     return value
#     611 if hasattr(self, 'validate'):
# --> 612     value = self.validate(obj, value)
#     613 if obj._cross_validation_lock is False:
#     614     value = self._cross_validate(obj, value)
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:2301, in Enum.validate(self, obj, value)
#    2299 if value in self.values:
#    2300         return value
# -> 2301 self.error(obj, value)
#
# File D:\Programs\Anaconda\lib\site-packages\traitlets\traitlets.py:692, in TraitType.error(self, obj, value, error, info)
#     689 else:
#     690     e = "The '%s' trait expected %s, not %s." % (
#     691         self.name, self.info(), describe("the", value))
# --> 692 raise TraitError(e)
#
# TraitError: The 'marker' trait of a Scatter instance expected any of ['circle', 'cross', 'diamond', 'square', 'triangle-down', 'triangle-up', 'arrow', 'rectangle', 'ellipse'], not the list ['triangle-up'].
